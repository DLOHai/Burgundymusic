# %%
# !pip list
# Out:
# Package              Version
# -------------------- --------------------
# absl-py              0.7.1
# alembic              1.0.11
# appdirs              1.4.3
# asciimatics          1.11.0
# asn1crypto           0.24.0
# astor                0.8.0
# attrs                19.1.0
# backcall             0.1.0
# bleach               3.1.0
# boto3                1.9.115
# botocore             1.12.180
# certifi              2018.1.18
# cffi                 1.12.3
# chardet              3.0.4
# Click                7.0
# cloudpickle          1.1.1
# colorama             0.4.1
# config               0.4.2
# configobj            5.0.6
# configparser         3.7.4
# contextlib2          0.5.5
# cryptography         2.1.4
# databricks-cli       0.8.7
# decorator            4.4.0
# defusedxml           0.6.0
# distro               1.4.0
# docker               4.0.2
# docutils             0.14
# dvc                  0.50.1
# entrypoints          0.3
# Flask                1.0.3
# ...

# %% [markdown]
# ### 1st error
# - tensorboard image summary

# %%
# !python generate.py --load_path='./result'
# Out:
# 2019-09-03 04:39:51.013107: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcuda.so.1
# 2019-09-03 04:39:51.031071: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1006] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-09-03 04:39:51.031630: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1640] Found device 0 with properties:
# name: GeForce RTX 2070 major: 7 minor: 5 memoryClockRate(GHz): 1.44
# pciBusID: 0000:01:00.0
# 2019-09-03 04:39:51.031835: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudart.so.10.0
# 2019-09-03 04:39:51.032951: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcublas.so.10.0
# ...

# %% [markdown]
# ### 2nd error
# - dimension error

# %%
# !python generate.py --load_path='./result'
# Out:
# 2019-09-03 04:42:50.745126: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcuda.so.1
# 2019-09-03 04:42:50.764070: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1006] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-09-03 04:42:50.764777: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1640] Found device 0 with properties:
# name: GeForce RTX 2070 major: 7 minor: 5 memoryClockRate(GHz): 1.44
# pciBusID: 0000:01:00.0
# 2019-09-03 04:42:50.765061: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudart.so.10.0
# 2019-09-03 04:42:50.766771: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcublas.so.10.0
# ...

# %% [markdown]
# ### 3rd error
# - [:,:,-1]로 바꿔줘도 문제

# %%
# !python generate.py --load_path='./result'
# Out:
# 2019-09-03 04:46:06.253311: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcuda.so.1
# 2019-09-03 04:46:06.288329: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1006] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-09-03 04:46:06.289390: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1640] Found device 0 with properties:
# name: GeForce RTX 2070 major: 7 minor: 5 memoryClockRate(GHz): 1.44
# pciBusID: 0000:01:00.0
# 2019-09-03 04:46:06.289670: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudart.so.10.0
# 2019-09-03 04:46:06.290950: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcublas.so.10.0
# ...
